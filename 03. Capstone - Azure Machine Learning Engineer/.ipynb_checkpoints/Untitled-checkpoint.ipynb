# %%
import pandas as pd

# %%
df = pd.read_csv("data/dataset_test.csv")

# %%
df.head().T
# Out:
#                                                  0          1          2  \
# key_value                                 0.000000   1.000000   2.000000
# target                                    0.000000   0.000000   0.000000
# edad                                      1.137034  -1.513823  -1.135129
# sexo                                      0.000000   0.000000   0.000000
# est_cvl                                   4.000000   4.000000   4.000000
# sit_lab                                   2.000000   1.000000   1.000000
# ctd_hijos                                 0.000000   0.000000   0.000000
# flg_sin_email                             0.000000   1.000000   0.000000
# ctd_veh                                   0.000000   0.000000   0.000000
# tip_lvledu                                0.000000   7.000000   5.000000
# total_mean_of_saldo_count_per_month      17.333333   4.916667   7.500000
# total_sum_of_saldo_count_per_month      208.000000  59.000000  90.000000
# ...

# %%
df.loc[60:61, :].to_dict(orient="records")
# Out:
# [{'key_value': 62,
#   'target': 0,
#   'edad': -1.3623451,
#   'sexo': 1.0,
#   'est_cvl': 4.0,
#   'sit_lab': 1.0,
#   'ctd_hijos': 0.0,
#   'flg_sin_email': 1.0,
#   'ctd_veh': 0.0,
#   'tip_lvledu': 7.0,
#   'total_mean_of_saldo_count_per_month': 2.5,
#   'total_sum_of_saldo_count_per_month': 30,
#   'total_min_of_saldo_count_per_month': 2,
#   'total_max_of_saldo_count_per_month': 4,
#   'total_mean_of_saldo_sum_per_month': 2.3570971,
#   'total_sum_of_saldo_sum_per_month': 28.285166,
#   'total_min_of_saldo_sum_per_month': 1.8607771,
#   'total_max_of_saldo_sum_per_month': 3.949139,
#   'total_min_of_saldo_min_per_month': 0.92711896,
#   'total_mean_of_saldo_min_per_month': 0.9273224,
#   'total_max_of_saldo_max_per_month': 1.04637,
#   'total_mean_of_saldo_max_per_month': 0.9552064,
#   'total_min_of_condicion_min_per_month': 0,
#   'total_mean_of_condicion_min_per_month': 0.0,
#   'total_max_of_condicion_max_per_month': 0,
#   'total_mean_of_condicion_max_per_month': 0.0,
# ...

# %%
df_train = pd.read_csv("data/dataset_train.csv")

# %%
df_train["target"].value_counts()
# Out:
# 0    298656
# 1     56007
# Name: target, dtype: int64

# %%
df_train.shape
# Out:
# (354663, 27)
